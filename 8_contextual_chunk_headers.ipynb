# %%
import os
from dotenv import load_dotenv

from pydantic import BaseModel, Field
from typing import List
from langchain.output_parsers import PydanticOutputParser

# LangChain components
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain.vectorstores import FAISS
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.schema import Document
import cohere

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    timeout=None,
    max_retries=2,
    # other params...
)

base_embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

# %%
annual_report_text = 'RAG_TECHNIQUES/data/nike_2023_annual_report.txt'

loader = TextLoader(annual_report_text)
docs = loader.load()

# %%
class Header(BaseModel):
    """The single-sentence summary of a text chunk."""
    header: str = Field(
        description="A single-sentence summary of the main topics and concepts in the text."
    )

# Create the parser
header_parser = PydanticOutputParser(pydantic_object=Header)

# Create the prompt
header_prompt = PromptTemplate(
    template="""You are an expert at summarizing technical documents. Your task is to generate a concise, single-sentence summary of the following text. This summary will be used as a contextual header for smaller text chunks during a vector search. Focus on the main topics and key entities.

Text:
{text}

{format_instructions}
""",
    input_variables=["text"],
    partial_variables={"format_instructions": header_parser.get_format_instructions()}
)

# Create the chain
header_generation_chain = header_prompt | llm | header_parser

# %%
# Create the parent splitter
parent_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=2000, chunk_overlap=200
)

# Create the child splitter
child_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=400, chunk_overlap=0
)

# Split the document into parent and child chunks
parent_chunks = parent_splitter.split_documents(docs)
child_chunks = child_splitter.split_documents(docs)

print(f"Created {len(parent_chunks)} parent chunks and {len(child_chunks)} child chunks.")
# Out:
# Created 48 parent chunks and 222 child chunks.

# %%
contextual_chunks = []
processed_child_indices = set() # To avoid processing a child chunk more than once

# Iterate through each parent chunk
for i, parent_chunk in enumerate(parent_chunks):
    print(f"Processing parent chunk {i+1}/{len(parent_chunks)}...")
    
    # --- Best Practice: Robust Error Handling ---
    try:
        # Generate the header
        header = header_generation_chain.invoke({"text": parent_chunk.page_content})
        print(f"  Generated Header: {header.header}")
        
        # Find all child chunks contained within this parent chunk
        for j, child_chunk in enumerate(child_chunks):
            if j not in processed_child_indices and child_chunk.page_content in parent_chunk.page_content:
                # Prepend the header to the child chunk's content
                new_content = f"CONTEXT: {header.header}\n\n---\n\n{child_chunk.page_content}"
                
                # Create a new Document object with the modified content
                contextual_doc = Document(page_content=new_content, metadata=child_chunk.metadata)
                contextual_chunks.append(contextual_doc)
                processed_child_indices.add(j)

    except Exception as e:
        print(f"  Error processing parent chunk {i+1}: {e}")

print(f"\nCreated {len(contextual_chunks)} contextual chunks.")
# Out:
# Processing parent chunk 1/48...
#   Generated Header: NIKE, Inc.'s Form 10-K annual report for the fiscal year ended May 31, 2023, details the company's global business as the largest seller of athletic footwear, apparel, equipment, and services.
# Processing parent chunk 2/48...
#   Generated Header: NIKE, Inc. designs, markets, and sells a diverse range of athletic and casual footwear, apparel, equipment, and digital services globally under its NIKE, Jordan, and Converse brands, with 57% of FY23 revenues from international markets, distributed through wholesale and direct-to-consumer channels, emphasizing innovation.
# Processing parent chunk 3/48...
#   Generated Header: Nike's product development integrates diverse specialists and athlete feedback to innovate technologies, while its global manufacturing relies on a vast network of international contract manufacturers and suppliers, navigating complex international trade policies and a highly competitive market.
# Processing parent chunk 4/48...
#   Generated Header: NIKE, INC. details its international compliance with anti-bribery laws, navigates intense global competition in athletic footwear and apparel, vigorously protects its intellectual property including NIKE and Swoosh trademarks, and prioritizes human capital through a diverse workforce, strong culture, and DE&I initiatives.
# Processing parent chunk 5/48...
#   Generated Header: NIKE details its strategic commitments to Diversity, Equity, and Inclusion (DE&I) and comprehensive employee compensation and well-being benefits, along with information on its executive officers and public filings.
# Processing parent chunk 6/48...
#   Generated Header: This text details the executive roles and backgrounds of NIKE leaders Monique S. Matheson, Ann M. Miller, Heidi O'Neill, and Craig Williams, alongside a discussion of NIKE's forward-looking statements and various risk factors, including economic and industry challenges.
# Processing parent chunk 7/48...
#   Generated Header: NIKE faces significant risks from global economic conditions, including inflation and currency volatility, intense competition in the athletic and leisure market, and the financial health of its wholesale customers, all of which could adversely affect its sales, costs, and financial results.
# Processing parent chunk 8/48...
#   Generated Header: Our business faces significant risks from financially struggling retailers, climate change and sustainability matters, extreme weather, natural disasters, and public health emergencies, which can disrupt operations, supply chains, and consumer demand.
# Processing parent chunk 9/48...
#   Generated Header: NIKE, INC. faces diverse risks including supply chain and operational disruptions from public health emergencies, challenges in maintaining brand reputation and adapting to consumer preferences, and financial volatility due to seasonality and market conditions.
# Processing parent chunk 10/48...
#   Generated Header: The company's success hinges on its ability to adapt to evolving consumer preferences, innovate products, maintain quality, manage endorser relationships, accurately forecast demand, and effectively operate its NIKE Direct retail and digital commerce platforms amidst various operational and technological risks.
# Processing parent chunk 11/48...
#   Generated Header: This document outlines business risks associated with digital commerce platforms, information technology systems, and dependencies on licensees, consolidated retailers, financial counterparties, and concentrated manufacturers.
# Processing parent chunk 12/48...
#   Generated Header: This text details various operational and financial risks, encompassing counterparty defaults, reliance on concentrated global contract manufacturers, real estate challenges, human capital and labor regulation issues, and inherent risks of international operations and sourcing.
# Processing parent chunk 13/48...
#   Generated Header: NIKE faces substantial risks across its global supply chain, encompassing overseas sourcing, manufacturing, and distribution, alongside complex legal, regulatory, and trade policy challenges that could severely impact its business operations and financial results.
# Processing parent chunk 14/48...
#   Generated Header: The company faces significant risks from changing international trade policies, anti-corruption laws, intellectual property infringement, data security breaches, evolving privacy regulations, and new tax laws, all of which could adversely impact its business and financial performance.
# Processing parent chunk 15/48...
#   Generated Header: The company faces risks from evolving global tax regulations and audits, non-compliance by contractors and licensees, and various financial and operational challenges including investment performance, market liquidity, and internal control effectiveness.
# Processing parent chunk 16/48...
#   Generated Header: NIKE discusses risks related to critical accounting estimates, market expectations, and anti-takeover provisions, while also detailing its global properties and outlining its common stock market and share repurchase programs.
# Processing parent chunk 17/48...
#   Generated Header: This text covers NIKE's share repurchase program, a five-year stock performance comparison against market indices, its global business strategy, fiscal 2023 financial highlights, and the impact of current economic conditions on its operations.
# Processing parent chunk 18/48...
#   Generated Header: NIKE, Inc. reported fiscal 2023 financial results, detailing efforts to manage inventory, overcome COVID-19 impacts in Greater China, mitigate foreign currency headwinds, and implement a new distributor model in Central and South America, alongside explanations of non-GAAP financial measures.
# Processing parent chunk 19/48...
#   Generated Header: This document presents NIKE, Inc.'s consolidated operating results and detailed revenue breakdowns for the NIKE Brand and Converse across fiscal years 2021-2023, including expenses, net income, and earnings per share.
# Processing parent chunk 20/48...
#   Generated Header: For fiscal 2023, NIKE reported increased NIKE Brand apparel and NIKE Direct revenues, a decline in gross margin driven by higher costs and promotions, and higher selling and administrative expenses and effective tax rates, with regional revenue growth varying.
# Processing parent chunk 21/48...
#   Generated Header: NIKE, INC. presents its fiscal 2023, 2022, and 2021 revenues and Earnings Before Interest and Taxes (EBIT) by geographic segment and product, detailing performance drivers and currency impacts.
# Processing parent chunk 22/48...
#   Generated Header: NIKE, Inc.'s Fiscal 2023 financial performance, including revenues and EBIT, is detailed for EMEA, Greater China, and APLA segments, analyzing product categories, sales channels, currency impacts, and contributing factors compared to Fiscal 2022.
# Processing parent chunk 23/48...
#   Generated Header: NIKE completed its CASA marketplace transition to a distributor model, impacting APLA's strong revenue growth, while Converse also grew, and all segments experienced varied financial performance in fiscal 2023 due to factors like product costs, pricing, and foreign currency.
# Processing parent chunk 24/48...
#   Generated Header: The text details the components and fiscal 2023 increase of Corporate's loss before interest and taxes, primarily driven by unallocated expenses and significant foreign currency impacts, and comprehensively describes NIKE's foreign currency risk management program, including transactional and translational exposures and hedging strategies.
# Processing parent chunk 25/48...
#   Generated Header: This text describes the financial impact and management of foreign currency translational exposures on consolidated results, and details the company's cash flow activities, share repurchases, and capital resources including credit facilities and debt.
# Processing parent chunk 26/48...
#   Generated Header: This text details the company's credit facilities, including a new $1 billion agreement, its long-term debt ratings and covenant compliance, liquidity sources like $10.7 billion in cash and investments, and material cash requirements for debt, leases, endorsement contracts, and product purchase obligations.
# Processing parent chunk 27/48...
#   Generated Header: This document outlines the company's critical accounting estimates for U.S. GAAP financial statements, including sales-related and inventory reserves, hedge accounting for derivatives, income taxes, and other contingencies, alongside its strategies for managing market risks from foreign currency and interest rate fluctuations.
# Processing parent chunk 28/48...
#   Generated Header: The Company manages foreign currency and interest rate market risks using derivative hedging strategies and a diversified debt portfolio, measures these exposures with tools like Value-at-Risk (VaR), and ensures financial reporting reliability through internal controls.
# Processing parent chunk 29/48...
#   Generated Header: PricewaterhouseCoopers LLP issued an opinion on NIKE, Inc.'s consolidated financial statements and the effectiveness of its internal control over financial reporting as of May 31, 2023, concluding both were effective, and highlighted accounting for income taxes as a critical audit matter.
# Processing parent chunk 30/48...
#   Generated Header: PricewaterhouseCoopers LLP's critical audit matter for NIKE, INC.'s income tax provision, emphasizing auditor judgment and complex tax laws, precedes the company's consolidated financial statements for 2021-2023, including income, balance sheet, and cash flow data.
# Processing parent chunk 31/48...
#   Generated Header: NIKE, Inc.'s financial disclosures include detailed cash flow and shareholders' equity statements, a summary of significant accounting policies, its business description, and revenue recognition practices.
# Processing parent chunk 32/48...
#   Generated Header: This document outlines the Company's accounting policies for revenue recognition, sales-related reserves, and the classification and measurement of Cost of Sales, Demand Creation, and Operating Overhead expenses, along with the valuation of Cash, Investments, Accounts Receivable, and Inventory.
# Processing parent chunk 33/48...
#   Generated Header: This document details the company's accounting policies and valuation methodologies for various assets and liabilities, including uncollectible accounts, inventory, property, plant and equipment, software development costs, long-lived asset impairment, goodwill, indefinite-lived intangibles, operating leases, and fair value measurements.
# Processing parent chunk 34/48...
#   Generated Header: The Company's accounting policies are detailed, covering fair value measurements, foreign currency, derivatives, stock-based compensation, income taxes, earnings per share, management estimates, and recent accounting standards, complemented by financial data for property, plant, equipment, and accrued liabilities.
# Processing parent chunk 35/48...
#   Generated Header: This text summarizes the Company's accrued liabilities, fair value measurements of financial assets and derivative instruments, and details on short-term borrowings and credit facilities.
# Processing parent chunk 36/48...
#   Generated Header: NIKE, INC. details its committed credit facilities, long-term debt composition and fair value, and income tax provisions with an analysis of its effective tax rate and the impact of tax law changes and restructuring.
# Processing parent chunk 37/48...
#   Generated Header: NIKE, INC. details its tax restructuring, including the onshoring of non-U.S. intangible property, its impact on effective tax rates and deferred tax assets and liabilities, and provides updates on unrecognized tax benefits and ongoing tax audits and investigations.
# Processing parent chunk 38/48...
#   Generated Header: This text details The Company's financial position regarding loss carry-forwards, redeemable preferred stock held by Sojitz America, common stock structure and repurchase programs, and comprehensive stock-based compensation plans, including stock options, restricted stock units, and employee stock purchase plans, along with their financial impact.
# Processing parent chunk 39/48...
#   Generated Header: This document details the Company's employee stock-based compensation (ESPPs, restricted stock/units), various benefit plans, earnings per share, and financial risk management using derivatives.
# Processing parent chunk 40/48...
#   Generated Header: This text details NIKE, INC.'s derivative assets and liabilities, including foreign exchange forwards and options, and their financial statement impact, with a focus on cash flow hedge accounting and the company's foreign exchange risk management program.
# Processing parent chunk 41/48...
#   Error processing parent chunk 41: Invalid json output:
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Processing parent chunk 42/48...
#   Generated Header: NIKE, INC.'s financial data includes gains/losses from foreign exchange and interest rate derivatives, and detailed revenue disaggregation by geographic segment, product line, and sales channel for fiscal years 2021-2023, along with sales-related reserves.
# Processing parent chunk 43/48...
#   Generated Header: The text details NIKE, INC.'s operating segments—North America, EMEA, Greater China, APLA, Global Brand Divisions, Converse, and Corporate—presenting their revenues, EBIT, and balance sheet items for 2021-2023, along with sales-related reserve balances, inventory for returns, and foreign exchange risk management practices.
# Processing parent chunk 44/48...
#   Generated Header: NIKE's financial notes detail geographic revenues and long-lived assets, commitments and contingencies including a Belgian customs claim, lease obligations, and a $550 million loss from the divestiture of entities in Argentina and Uruguay.
# Processing parent chunk 45/48...
#   Generated Header: This document outlines the Company's financial reporting for asset divestitures, including reclassification of losses and held-for-sale assets, fiscal 2021 restructuring expenses, and details on disclosure and internal control effectiveness, alongside references to other SEC filing sections.
# Processing parent chunk 46/48...
#   Generated Header: This 2023 Form 10-K section details NIKE, Inc.'s financial statements for fiscal years 2021-2023, including income, balance, and cash flow, alongside corporate governance, debt, and executive compensation exhibits.
# Processing parent chunk 47/48...
#   Generated Header: This Form 10-K section for NIKE, Inc. outlines various executive compensation and stock incentive plans, credit agreements, financial schedules, auditor consents, and the signatures of its principal officers and directors.
# Processing parent chunk 48/48...
#   Generated Header: A 2023 Form 10-K document outlining NIKE, Inc.'s directors, corporate officers, board committee assignments, global headquarters, shareholder information, independent accountants, and stock transfer agent.
#
# Created 196 contextual chunks.

# %%
print("--- EXAMPLE: Before (Naive Chunk) ---")
print(child_chunks[2].page_content)
print("\n" + "="*80 + "\n")
print("--- EXAMPLE: After (Contextual Chunk) ---")
# Find the corresponding contextual chunk
# Note: The index might not match exactly due to processing order, so we search
corresponding_contextual_chunk = next(c for c in contextual_chunks if child_chunks[2].page_content in c.page_content)
print(corresponding_contextual_chunk.page_content)
# Out:
# --- EXAMPLE: Before (Naive Chunk) ---
# the registered public accounting firm that prepared or issued its audit report.þ
# •if securities are registered pursuant to Section 12(b) of the Act, whether the financial statements of the registrant
# included in the filing reflect the correction of an error to previously issued financial statements. ¨
# •whether any of those error corrections are restatements that required a recovery analysis of incentive-based
# compensation received by any of the registrant's executive officers during the relevant recovery period pursuant to
# § 240.10D-1(b). ¨
# •whether the registrant is a shell company (as defined in Rule 12b-2 of the Act). ☐ þ
# As of November 30, 2022, the aggregate market values of the Registrant's Common Stock held by non-affiliates were:
# Class A $ 7,831,564,572
# Class B 136,467,702,472
# $ 144,299,267,044 As of July 12, 2023, the number of shares of the Registrant's Common Stock outstanding were:
# Class A  304,897,252
# Class B  1,225,074,356
#  1,529,971,608
# DOCUMENTS INCORPORATED BY REFERENCE:
# Parts of Registrant's Proxy Statement for the Annual Meeting of Shareholders to be held on September 12, 2023, are incorporated by reference into Part III
# of this report.NIKE, INC.
# ANNUAL REPORT ON FORM 10-K
# TABLE OF CONTENTS
# PAGE
# PART I 1
# ITEM 1. Business 1
# General 1
# Products 1
# Sales and Marketing 2
# Our Markets 2
# Significant Customer 3
# Product Research, Design and Development 3
# Manufacturing 3
# International Operations and Trade 4
# Competition 5
# Trademarks and Patents 5
#
# ================================================================================
#
# --- EXAMPLE: After (Contextual Chunk) ---
# CONTEXT: NIKE, Inc.'s Form 10-K annual report for the fiscal year ended May 31, 2023, details the company's global business as the largest seller of athletic footwear, apparel, equipment, and services.
#
# ---
#
# the registered public accounting firm that prepared or issued its audit report.þ
# •if securities are registered pursuant to Section 12(b) of the Act, whether the financial statements of the registrant
# included in the filing reflect the correction of an error to previously issued financial statements. ¨
# •whether any of those error corrections are restatements that required a recovery analysis of incentive-based
# compensation received by any of the registrant's executive officers during the relevant recovery period pursuant to
# § 240.10D-1(b). ¨
# •whether the registrant is a shell company (as defined in Rule 12b-2 of the Act). ☐ þ
# As of November 30, 2022, the aggregate market values of the Registrant's Common Stock held by non-affiliates were:
# Class A $ 7,831,564,572
# Class B 136,467,702,472
# $ 144,299,267,044 As of July 12, 2023, the number of shares of the Registrant's Common Stock outstanding were:
# Class A  304,897,252
# Class B  1,225,074,356
#  1,529,971,608
# DOCUMENTS INCORPORATED BY REFERENCE:
# Parts of Registrant's Proxy Statement for the Annual Meeting of Shareholders to be held on September 12, 2023, are incorporated by reference into Part III
# of this report.NIKE, INC.
# ANNUAL REPORT ON FORM 10-K
# TABLE OF CONTENTS
# PAGE
# PART I 1
# ITEM 1. Business 1
# General 1
# Products 1
# Sales and Marketing 2
# Our Markets 2
# Significant Customer 3
# Product Research, Design and Development 3
# Manufacturing 3
# International Operations and Trade 4
# Competition 5
# Trademarks and Patents 5

# %%
import time
from typing import List
from langchain_core.documents import Document

def create_vectorstore_in_batches(
    documents: List[Document], 
    embedding_model, 
    batch_size: int = 32, 
    delay_seconds: float = 1.0
):
    """
    Creates a FAISS vector store by processing documents in batches with a delay
    to respect API rate limits.
    """
    vectorstore = None
    
    # Iterate over the documents in batches
    for i in range(0, len(documents), batch_size):
        # Get the current batch of documents
        batch = documents[i:i+batch_size]
        
        print(f"  Processing batch {i//batch_size + 1}/{(len(documents) + batch_size - 1)//batch_size}...")
        
        if vectorstore is None:
            # For the first batch, create the vector store
            vectorstore = FAISS.from_documents(documents=batch, embedding=embedding_model)
        else:
            # For subsequent batches, add to the existing vector store
            vectorstore.add_documents(documents=batch)
            
        # --- THIS IS THE CRUCIAL PART ---
        # Add a delay to stay under the rate limit
        print(f"  Waiting for {delay_seconds} second(s) to respect rate limits...")
        time.sleep(delay_seconds)
        
    return vectorstore

# %%
SAFE_BATCH_SIZE = 8
SAFE_DELAY_SECONDS = 8 # A little extra buffer

# Create the naive vector store using our new safe parameters
print("Creating naive vector store in batches (TPM-aware)...")
vectorstore_naive = create_vectorstore_in_batches(
    documents=child_chunks, 
    embedding_model=base_embeddings,
    batch_size=SAFE_BATCH_SIZE,
    delay_seconds=SAFE_DELAY_SECONDS
)
retriever_naive = vectorstore_naive.as_retriever(search_kwargs={'k': 5})

print("\n" + "="*80 + "\n")

# Create the contextual vector store using the same safe parameters
print("Creating contextual vector store in batches (TPM-aware)...")
vectorstore_contextual = create_vectorstore_in_batches(
    documents=contextual_chunks, 
    embedding_model=base_embeddings,
    batch_size=SAFE_BATCH_SIZE,
    delay_seconds=SAFE_DELAY_SECONDS
)
retriever_contextual = vectorstore_contextual.as_retriever(search_kwargs={'k': 5})

print("\n✅ Vector stores are ready.")
# Out:
# Creating naive vector store in batches (TPM-aware)...
#   Processing batch 1/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 2/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 3/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 4/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 5/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 6/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 7/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 8/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 9/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 10/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 11/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 12/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 13/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 14/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 15/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 16/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 17/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 18/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 19/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 20/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 21/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 22/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 23/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 24/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 25/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 26/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 27/28...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 28/28...
#   Waiting for 8 second(s) to respect rate limits...
#
# ================================================================================
#
# Creating contextual vector store in batches (TPM-aware)...
#   Processing batch 1/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 2/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 3/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 4/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 5/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 6/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 7/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 8/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 9/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 10/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 11/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 12/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 13/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 14/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 15/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 16/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 17/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 18/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 19/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 20/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 21/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 22/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 23/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 24/25...
#   Waiting for 8 second(s) to respect rate limits...
#   Processing batch 25/25...
#   Waiting for 8 second(s) to respect rate limits...
#
# ✅ Vector stores are ready.

# %%
from langchain.retrievers import ContextualCompressionRetriever
from langchain_cohere import CohereRerank

compressor = CohereRerank(
    model="rerank-english-v3.0", 
    top_n=3, 
)

compression_retriever_naive = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=retriever_naive
)

compression_retriever_contextual = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=retriever_contextual
)

# %%
query = "Nike's sales statistics"
print(f"\nQUERY: '{query}'\n")

# --- Test the Naive Retriever + Cohere Reranker ---
print("--- 1. Testing Naive Retriever + Cohere Reranker ---")
reranked_naive_results = compression_retriever_naive.invoke(query)

for i, doc in enumerate(reranked_naive_results):
    # The CohereRerank compressor automatically adds the 'relevance_score' to the metadata
    score = doc.metadata['relevance_score']
    print(f"\n[Rank {i+1}] Relevance Score: {score:.4f}")
    print(f"Content: {doc.page_content}")

print("\n" + "="*80 + "\n")

# --- Test the Contextual Retriever + Cohere Reranker ---
print("--- 2. Testing Contextual Retriever + Cohere Reranker ---")
reranked_contextual_results = compression_retriever_contextual.invoke(query)

for i, doc in enumerate(reranked_contextual_results):
    score = doc.metadata['relevance_score']
    print(f"\n[Rank {i+1}] Relevance Score: {score:.4f}")
    print(f"Content: {doc.page_content}")
# Out:
# QUERY: 'Nike's sales statistics'
#
# --- 1. Testing Naive Retriever + Cohere Reranker ---
#
# [Rank 1] Relevance Score: 0.9900
# Content: NIKE Brand Revenues by:
# Sales to Wholesale Customers $ 27,397 $ 25,608  7 %  14 % $ 25,898  -1 %  -1 %
# Sales through NIKE Direct  21,308  18,726  14 %  20 %  16,370  14 %  15 %
# Global Brand Divisions(2) 58  102  -43 %  -43 %  25  308 %  302 %
# TOTAL NIKE BRAND REVENUES $ 48,763 $ 44,436  10 %  16 % $ 42,293  5 %  6 %
# NIKE Brand Revenues on a Wholesale Equivalent
# Basis(1):
# Sales to Wholesale Customers $ 27,397 $ 25,608  7 %  14 % $ 25,898  -1 %  -1 %
# Sales from our Wholesale Operations to NIKE Direct
# Operations  12,730  10,543  21 %  27 %  9,872  7 %  7 %
# TOTAL NIKE BRAND WHOLESALE EQUIVALENT
# REVENUES $ 40,127 $ 36,151  11 %  18 % $ 35,770  1 %  1 %
# NIKE Brand Wholesale Equivalent Revenues by:(1),(4)
# Men's $ 20,733 $ 18,797  10 %  17 % $ 18,391  2 %  3 %
# Women's  8,606  8,273  4 %  11 %  8,225  1 %  1 %
# NIKE Kids'  5,038  4,874  3 %  10 %  4,882  0 %  0 %
#
# [Rank 2] Relevance Score: 0.9679
# Content: Asia Pacific & Latin America  6,431  5,955  5,343
# Global Brand Divisions  58  102  25
# Total NIKE Brand  48,763  44,436  42,293
# Converse  2,427  2,346  2,205
# Corporate  27  (72)  40
# TOTAL NIKE, INC. REVENUES $ 51,217 $ 46,710 $ 44,538
# EARNINGS BEFORE INTEREST AND TAXES
# North America $ 5,454 $ 5,114 $ 5,089
# Europe, Middle East & Africa  3,531  3,293  2,435
# Greater China  2,283  2,365  3,243
# Asia Pacific & Latin America  1,932  1,896  1,530
# Global Brand Divisions  (4,841)  (4,262)  (3,656)
# Converse  676  669  543
# Corporate  (2,840)  (2,219)  (2,261)
# Interest expense (income), net  (6)  205  262
# TOTAL NIKE, INC. INCOME BEFORE INCOME TAXES $ 6,201 $ 6,651 $ 6,661
# ADDITIONS TO PROPERTY, PLANT AND EQUIPMENT
# North America $ 283 $ 146 $ 98
# Europe, Middle East & Africa  215  197  153
# Greater China  56  78  94
# Asia Pacific & Latin America  64  56  54
# Global Brand Divisions  271  222  278
# Total NIKE Brand  889  699  677
# Converse  7  9  7
#
# [Rank 3] Relevance Score: 0.9610
# Content: AMERICAEUROPE,
# MIDDLE
# EAST &
# AFRICAGREATER
# CHINAASIA
# PACIFIC &
# LATIN
# AMERICA(1)GLOBAL
# BRAND
# DIVISIONSTOTAL
# NIKE
# BRAND CONVERSE CORPORATETOTAL
# NIKE, INC.
# Revenues by:
# Footwear $ 11,644 $ 6,970 $ 5,748 $ 3,659 $ — $ 28,021 $ 1,986 $ — $ 30,007
# Apparel  5,028  3,996  2,347  1,494  —  12,865  104  —  12,969
# Equipment  507  490  195  190  —  1,382  29  —  1,411
# Other  —  —  —  —  25  25  86  40  151
# TOTAL REVENUES $ 17,179 $ 11,456 $ 8,290 $ 5,343 $ 25 $ 42,293 $ 2,205 $ 40 $ 44,538
# Revenues by:
# Sales to Wholesale
# Customers $ 10,186 $ 7,812 $ 4,513 $ 3,387 $ — $ 25,898 $ 1,353 $ — $ 27,251
# Sales through Direct to
# Consumer  6,993  3,644  3,777  1,956  —  16,370  766  —  17,136
# Other  —  —  —  —  25  25  86  40  151
#
# ================================================================================
#
# --- 2. Testing Contextual Retriever + Cohere Reranker ---
#
# [Rank 1] Relevance Score: 0.9891
# Content: CONTEXT: NIKE, INC.'s financial data includes gains/losses from foreign exchange and interest rate derivatives, and detailed revenue disaggregation by geographic segment, product line, and sales channel for fiscal years 2021-2023, along with sales-related reserves.
#
# ---
#
# AMERICAEUROPE,
# MIDDLE
# EAST &
# AFRICAGREATER
# CHINAASIA
# PACIFIC &
# LATIN
# AMERICA(1)GLOBAL
# BRAND
# DIVISIONSTOTAL
# NIKE
# BRAND CONVERSE CORPORATETOTAL
# NIKE, INC.
# Revenues by:
# Footwear $ 11,644 $ 6,970 $ 5,748 $ 3,659 $ — $ 28,021 $ 1,986 $ — $ 30,007
# Apparel  5,028  3,996  2,347  1,494  —  12,865  104  —  12,969
# Equipment  507  490  195  190  —  1,382  29  —  1,411
# Other  —  —  —  —  25  25  86  40  151
# TOTAL REVENUES $ 17,179 $ 11,456 $ 8,290 $ 5,343 $ 25 $ 42,293 $ 2,205 $ 40 $ 44,538
# Revenues by:
# Sales to Wholesale
# Customers $ 10,186 $ 7,812 $ 4,513 $ 3,387 $ — $ 25,898 $ 1,353 $ — $ 27,251
# Sales through Direct to
# Consumer  6,993  3,644  3,777  1,956  —  16,370  766  —  17,136
# Other  —  —  —  —  25  25  86  40  151
#
# [Rank 2] Relevance Score: 0.9871
# Content: CONTEXT: NIKE, INC.'s financial data includes gains/losses from foreign exchange and interest rate derivatives, and detailed revenue disaggregation by geographic segment, product line, and sales channel for fiscal years 2021-2023, along with sales-related reserves.
#
# ---
#
# Apparel  5,947  4,566  1,666  1,664  —  13,843  90  —  13,933
# Equipment  764  592  147  224  —  1,727  28  —  1,755
# Other  —  —  —  —  58  58  154  27  239
# TOTAL REVENUES $ 21,608 $ 13,418 $ 7,248 $ 6,431 $ 58 $ 48,763 $ 2,427 $ 27 $ 51,217
# Revenues by:
# Sales to Wholesale
# Customers $ 11,273 $ 8,522 $ 3,866 $ 3,736 $ — $ 27,397 $ 1,299 $ — $ 28,696
# Sales through Direct to
# Consumer  10,335  4,896  3,382  2,695  —  21,308  974  —  22,282
# Other  —  —  —  —  58  58  154  27  239
# TOTAL REVENUES $ 21,608 $ 13,418 $ 7,248 $ 6,431 $ 58 $ 48,763 $ 2,427 $ 27 $ 51,217
# (1) Refer to Note 18 — Acquisitions and Divestitures for additional information on the transition of the Company's NIKE Brand businesses in its CASA
# territory to third-party distributors.
# YEAR ENDED MAY 31, 2022
# (Dollars in millions)NORTH
# AMERICAEUROPE,
# MIDDLE
# EAST &
# AFRICAGREATER
# CHINAASIA
# PACIFIC &
# LATIN
# AMERICAGLOBAL
# BRAND
#
# [Rank 3] Relevance Score: 0.9831
# Content: CONTEXT: NIKE, INC.'s financial data includes gains/losses from foreign exchange and interest rate derivatives, and detailed revenue disaggregation by geographic segment, product line, and sales channel for fiscal years 2021-2023, along with sales-related reserves.
#
# ---
#
# DIVISIONSTOTAL
# NIKE
# BRAND CONVERSE CORPORATETOTAL
# NIKE, INC.
# Revenues by:
# Footwear $ 12,228 $ 7,388 $ 5,416 $ 4,111 $ — $ 29,143 $ 2,094 $ — $ 31,237
# Apparel  5,492  4,527  1,938  1,610  —  13,567  103  —  13,670
# Equipment  633  564  193  234  —  1,624  26  —  1,650
# Other  —  —  —  —  102  102  123  (72)  153
# TOTAL REVENUES $ 18,353 $ 12,479 $ 7,547 $ 5,955 $ 102 $ 44,436 $ 2,346 $ (72) $ 46,710
# Revenues by:
# Sales to Wholesale
# Customers $ 9,621 $ 8,377 $ 4,081 $ 3,529 $ — $ 25,608 $ 1,292 $ — $ 26,900
# Sales through Direct to
# Consumer  8,732  4,102  3,466  2,426  —  18,726  931  —  19,657
# Other  —  —  —  —  102  102  123  (72)  153
# TOTAL REVENUES $ 18,353 $ 12,479 $ 7,547 $ 5,955 $ 102 $ 44,436 $ 2,346 $ (72) $ 46,710
# 2023 FORM 10-K   83    YEAR ENDED MAY 31, 2021
# (Dollars in millions)NORTH
